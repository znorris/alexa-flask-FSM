# %% [markdown]
# # Daily Routine Finite-state machine (FSM)
# This FSM was designed with the purpose of creating a conversational flow for Amazon Alexa.
# We'll manually trigger state changes, called transitions in the `transitions` lib or intents on Alexa, and view what the FSM looks like at that time.

# %%
# Setup the notebook   
from transitions.extensions import GraphMachine as Machine
from IPython.display import Image, display, display_png

# %%
from machines.routine import DailyRoutineMachine
from random import random

# %%
# GraphMachine = MachineFactory.get_predefined(graph=True, nested=True)

# %%
from machines.routine import *

# %%
machine = DailyRoutineMachine('machine')
machine.show_graph()  # The current state should be in orange.
machine.state
# Out:
# 'awake'

# %%
machine.go_to_bed()
machine.show_graph()
machine.state
# Out:
# 'asleep'

# %%
machine.get_up()
machine.show_graph()

# %% [markdown]
# Begging had a 50/50 chance of happening. It would be looking for a `yes` or `no` transition now, after asking "Do I have to?"

# %%
machine.yes()
machine.show_graph()
